# %%
# Contract Analysis System - Complete Portfolio Overview
# 5-Phase Legal Tech Project Demonstration

# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set up plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("✅ Demo environment ready!")
# Out:
# ✅ Demo environment ready!

# %%
# Phase 1 Overview
phase1_data = {
    'Goal': 'Stand up clean, professional repo and reliable data pipeline',
    'Key Components': [
        'CUAD dataset ingestion → parsing → clause segmentation',
        'PDF/DOCX → text (OCR fallback)',
        'Data contracts (Pandera/Great Expectations)',
        'Baselines: TF-IDF + linear models for clause type',
        'Simple keyword risk heuristics',
        'EDA + class imbalance strategy'
    ],
    'Technology Stack': [
        'Python 3.11', 'Pandas', 'NumPy', 'spaCy (NER)',
        'scikit-learn', 'Pandera', 'DVC', 'Jupyter'
    ],
    'Expected Improvements': [
        'Baseline F1: 0.65-0.75',
        'Risk detection: 80%+ accuracy',
        'Processing speed: 10s/contract'
    ],
    'Business Impact': [
        'Automated clause classification',
        'Risk flag identification',
        'Standardized data pipeline'
    ],
    'Portfolio Value': 'Demonstrates solid ML foundations, data engineering, and legal domain understanding'
}

print("📊 Phase 1: Foundations & Data")
print("=" * 50)
for key, value in phase1_data.items():
    print(f"\n{key}:")
    if isinstance(value, list):
        for item in value:
            print(f"  • {item}")
    else:
        print(f"  {value}")
# Out:
# 📊 Phase 1: Foundations & Data
# ...
#
# Goal:
#   Stand up clean, professional repo and reliable data pipeline
#
# Key Components:
#   • CUAD dataset ingestion → parsing → clause segmentation
#   • PDF/DOCX → text (OCR fallback)
#   • Data contracts (Pandera/Great Expectations)
#   • Baselines: TF-IDF + linear models for clause type
#   • Simple keyword risk heuristics
#   • EDA + class imbalance strategy
#
# Technology Stack:
#   • Python 3.11
#   • Pandas
#   • NumPy
#   • spaCy (NER)
#   • scikit-learn
#   • Pandera
#   • DVC
#   • Jupyter
#
# Expected Improvements:
#   • Baseline F1: 0.65-0.75
#   • Risk detection: 80%+ accuracy
#   • Processing speed: 10s/contract
#
# Business Impact:
#   • Automated clause classification
#   • Risk flag identification
#   • Standardized data pipeline
#
# Portfolio Value:
#   Demonstrates solid ML foundations, data engineering, and legal domain understanding

# %%
# Phase 2 Overview
phase2_data = {
    'Goal': 'High-quality clause classification + explainable risk scoring',
    'Key Components': [
        'Fine-tune DistilBERT/Legal-BERT (seq_len 256-512)',
        'Multi-label classification head',
        'Calibrated probabilities + per-clause confidence',
        'Risk engine: policy rules + learned anomalies',
        'Composite risk = w₁·rule + w₂·model + w₃·anomaly',
        'Explainability: token-level highlights + SHAP'
    ],
    'Technology Stack': [
        'Transformers', 'PyTorch', 'SHAP', 'Legal-BERT',
        'MLflow', 'Optuna', 'Weights & Biases'
    ],
    'Expected Improvements': [
        'Macro F1: 0.80-0.85',
        'Risk precision: 85%+',
        'Confidence calibration: Brier < 0.1'
    ],
    'Business Impact': [
        'Contract type classification',
        'Risk trend analysis',
        'Negotiation suggestions'
    ],
    'Portfolio Value': 'Shows advanced NLP, model interpretability, and domain expertise'
}

print("\n📊 Phase 2: Advanced Modeling & Risk Scoring")
print("=" * 60)
for key, value in phase2_data.items():
    print(f"\n{key}:")
    if isinstance(value, list):
        for item in value:
            print(f"  • {item}")
    else:
        print(f"  {value}")
# Out:
# 📊 Phase 2: Advanced Modeling & Risk Scoring
# ...
#
# Goal:
#   High-quality clause classification + explainable risk scoring
#
# Key Components:
#   • Fine-tune DistilBERT/Legal-BERT (seq_len 256-512)
#   • Multi-label classification head
#   • Calibrated probabilities + per-clause confidence
#   • Risk engine: policy rules + learned anomalies
#   • Composite risk = w₁·rule + w₂·model + w₃·anomaly
#   • Explainability: token-level highlights + SHAP
#
# Technology Stack:
#   • Transformers
#   • PyTorch
#   • SHAP
#   • Legal-BERT
#   • MLflow
#   • Optuna
#   • Weights & Biases
#
# Expected Improvements:
#   • Macro F1: 0.80-0.85
#   • Risk precision: 85%+
#   • Confidence calibration: Brier < 0.1
#
# Business Impact:
#   • Contract type classification
#   • Risk trend analysis
#   • Negotiation suggestions
#
# Portfolio Value:
#   Shows advanced NLP, model interpretability, and domain expertise

# %%
# Phase 3 Overview
phase3_data = {
    'Goal': 'Usable demo for lawyers/product folks',
    'Key Components': [
        'FastAPI endpoints: /analyze_contract, /risk_report, /health',
        'Pydantic I/O schemas',
        'Streamlit UI with upload → clause highlights → per-clause analysis',
        'Contract summary: total risk, missing clauses, red-flag list',
        'Portfolio tab: multi-contract view',
        'Lightweight RAG: similar safe clauses + suggested wording'
    ],
    'Technology Stack': [
        'FastAPI', 'Streamlit', 'Docker', 'Pydantic',
        'ChromaDB', 'Sentence Transformers'
    ],
    'Expected Improvements': [
        'End-to-end flow: <10s/contract',
        'Deterministic results',
        'User-friendly interface'
    ],
    'Business Impact': [
        'ROI calculator',
        'Comparison tools',
        'Export formats (PDF/CSV)'
    ],
    'Portfolio Value': 'Demonstrates full-stack development, API design, and user experience'
}

print("\n📊 Phase 3: Product MVP")
print("=" * 40)
for key, value in phase3_data.items():
    print(f"\n{key}:")
    if isinstance(value, list):
        for item in value:
            print(f"  • {item}")
    else:
        print(f"  {value}")
# Out:
# 📊 Phase 3: Product MVP
# ...
#
# Goal:
#   Usable demo for lawyers/product folks
#
# Key Components:
#   • FastAPI endpoints: /analyze_contract, /risk_report, /health
#   • Pydantic I/O schemas
#   • Streamlit UI with upload → clause highlights → per-clause analysis
#   • Contract summary: total risk, missing clauses, red-flag list
#   • Portfolio tab: multi-contract view
#   • Lightweight RAG: similar safe clauses + suggested wording
#
# Technology Stack:
#   • FastAPI
#   • Streamlit
#   • Docker
#   • Pydantic
#   • ChromaDB
#   • Sentence Transformers
#
# Expected Improvements:
#   • End-to-end flow: <10s/contract
#   • Deterministic results
#   • User-friendly interface
#
# Business Impact:
#   • ROI calculator
#   • Comparison tools
#   • Export formats (PDF/CSV)
#
# Portfolio Value:
#   Demonstrates full-stack development, API design, and user experience

# %%
# Phase 4 Overview
phase4_data = {
    'Goal': 'Make it feel production-ready',
    'Key Components': [
        'MLflow tracking + Model Registry (Staging → Prod)',
        'Experiment tags tied to data hash',
        'DVC for data/version lineage',
        'GitHub Actions: tests, lint, data checks, build, deploy',
        'Hosting: API on VM/Railway, UI on Streamlit Cloud',
        'Monitoring: request/latency logs, drift detection'
    ],
    'Technology Stack': [
        'MLflow', 'DVC', 'GitHub Actions', 'Docker',
        'Prometheus', 'Grafana', 'RBAC'
    ],
    'Expected Improvements': [
        'One-click deploy from main',
        'Drift detection automation',
        'Compliance reporting'
    ],
    'Business Impact': [
        'Production-ready system',
        'Compliance documentation',
        'Audit trails'
    ],
    'Portfolio Value': 'Shows MLOps expertise, CI/CD, and production deployment skills'
}

print("\n📊 Phase 4: MLOps & Deployment")
print("=" * 50)
for key, value in phase4_data.items():
    print(f"\n{key}:")
    if isinstance(value, list):
        for item in value:
            print(f"  • {item}")
    else:
        print(f"  {value}")
# Out:
# 📊 Phase 4: MLOps & Deployment
# ...
#
# Goal:
#   Make it feel production-ready
#
# Key Components:
#   • MLflow tracking + Model Registry (Staging → Prod)
#   • Experiment tags tied to data hash
#   • DVC for data/version lineage
#   • GitHub Actions: tests, lint, data checks, build, deploy
#   • Hosting: API on VM/Railway, UI on Streamlit Cloud
#   • Monitoring: request/latency logs, drift detection
#
# Technology Stack:
#   • MLflow
#   • DVC
#   • GitHub Actions
#   • Docker
#   • Prometheus
#   • Grafana
#   • RBAC
#
# Expected Improvements:
#   • One-click deploy from main
#   • Drift detection automation
#   • Compliance reporting
#
# Business Impact:
#   • Production-ready system
#   • Compliance documentation
#   • Audit trails
#
# Portfolio Value:
#   Shows MLOps expertise, CI/CD, and production deployment skills

# %%
# Phase 5 Overview
phase5_data = {
    'Goal': 'Enterprise polish + recruiter magnet',
    'Key Components': [
        'Performance: batch pipeline, caching embeddings, GPU inference',
        'Load testing with Locust',
        'Configurable Legal Playbook (YAML)',
        'Exportable PDF/CSV reports with findings',
        'Compliance pack: GDPR, access control, SOC2-style checklist',
        'Case study: 50-100 real public contracts analysis'
    ],
    'Technology Stack': [
        'Locust', 'Redis', 'GPU acceleration', 'YAML configs',
        'ReportLab', 'Compliance frameworks'
    ],
    'Expected Improvements': [
        'P95 latency SLA',
        '1000+ clauses/day processing',
        'Documented ROI narrative'
    ],
    'Business Impact': [
        'Enterprise-ready solution',
        'Compliance certification',
        'ROI demonstration'
    ],
    'Portfolio Value': 'Demonstrates enterprise thinking, compliance knowledge, and business impact'
}

print("\n📊 Phase 5: Scale & Compliance")
print("=" * 50)
for key, value in phase5_data.items():
    print(f"\n{key}:")
    if isinstance(value, list):
        for item in value:
            print(f"  • {item}")
    else:
        print(f"  {value}")
# Out:
# 📊 Phase 5: Scale & Compliance
# ...
#
# Goal:
#   Enterprise polish + recruiter magnet
#
# Key Components:
#   • Performance: batch pipeline, caching embeddings, GPU inference
#   • Load testing with Locust
#   • Configurable Legal Playbook (YAML)
#   • Exportable PDF/CSV reports with findings
#   • Compliance pack: GDPR, access control, SOC2-style checklist
#   • Case study: 50-100 real public contracts analysis
#
# Technology Stack:
#   • Locust
#   • Redis
#   • GPU acceleration
#   • YAML configs
#   • ReportLab
#   • Compliance frameworks
#
# Expected Improvements:
#   • P95 latency SLA
#   • 1000+ clauses/day processing
#   • Documented ROI narrative
#
# Business Impact:
#   • Enterprise-ready solution
#   • Compliance certification
#   • ROI demonstration
#
# Portfolio Value:
#   Demonstrates enterprise thinking, compliance knowledge, and business impact

# %%
# Create project roadmap visualization
fig, ax = plt.subplots(figsize=(15, 10))

# Phase data
phases = ['Phase 1\nFoundations', 'Phase 2\nAdvanced ML', 'Phase 3\nProduct MVP', 'Phase 4\nMLOps', 'Phase 5\nScale']
complexity = [1, 3, 2, 4, 5]  # Relative complexity
duration = [2, 3, 2, 2, 3]   # Weeks
colors = ['#2E86AB', '#A23B72', '#F18F01', '#C73E1D', '#592E83']

# Create timeline
y_pos = np.arange(len(phases))
bars = ax.barh(y_pos, duration, color=colors, alpha=0.7)

# Add complexity indicators
for i, (phase, comp, dur) in enumerate(zip(phases, complexity, duration)):
    ax.text(dur/2, i, f'Complexity: {comp}/5', ha='center', va='center', 
            fontweight='bold', color='white')

# Customize plot
ax.set_yticks(y_pos)
ax.set_yticklabels(phases, fontsize=12, fontweight='bold')
ax.set_xlabel('Duration (Weeks)', fontsize=14, fontweight='bold')
ax.set_title('Contract Analysis System - 5-Phase Development Roadmap', 
             fontsize=16, fontweight='bold', pad=20)

# Add phase descriptions
descriptions = [
    'Data Pipeline + Baselines',
    'BERT Models + Risk Engine',
    'API + UI + RAG',
    'MLOps + Deployment',
    'Scale + Compliance'
]

for i, desc in enumerate(descriptions):
    ax.text(0, i, f'  {desc}', va='center', fontsize=10, style='italic')

plt.tight_layout()
plt.show()

# %%
# Define KPIs for each phase
kpi_data = {
    'Model Performance': {
        'Phase 1': 'F1 Macro: 0.65-0.75',
        'Phase 2': 'F1 Macro: 0.80-0.85',
        'Phase 3': 'End-to-end: <10s/contract',
        'Phase 4': 'P95 latency: <5s',
        'Phase 5': '1000+ clauses/day'
    },
    'Business Impact': {
        'Phase 1': 'Automated classification',
        'Phase 2': 'Risk trend analysis',
        'Phase 3': 'ROI calculator',
        'Phase 4': 'Production deployment',
        'Phase 5': 'Enterprise compliance'
    },
    'Technical Excellence': {
        'Phase 1': 'Clean code + tests',
        'Phase 2': 'Advanced NLP',
        'Phase 3': 'Full-stack demo',
        'Phase 4': 'MLOps pipeline',
        'Phase 5': 'Enterprise scale'
    }
}

# Create KPI visualization
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for idx, (kpi_type, data) in enumerate(kpi_data.items()):
    phases = list(data.keys())
    values = list(data.values())
    
    bars = axes[idx].bar(range(len(phases)), [1]*len(phases), 
                        color=colors[:len(phases)], alpha=0.7)
    
    # Add text labels
    for i, (phase, value) in enumerate(zip(phases, values)):
        axes[idx].text(i, 0.5, f'{phase}\n{value}', ha='center', va='center',
                      fontsize=9, fontweight='bold', color='white')
    
    axes[idx].set_title(kpi_type, fontsize=14, fontweight='bold')
    axes[idx].set_ylim(0, 1)
    axes[idx].set_xticks([])
    axes[idx].set_yticks([])

plt.tight_layout()
plt.show()

# %%
# Technology stack by phase
tech_stacks = {
    'Phase 1': ['Python', 'Pandas', 'NumPy', 'spaCy', 'scikit-learn', 'Pandera', 'DVC'],
    'Phase 2': ['Transformers', 'PyTorch', 'SHAP', 'Legal-BERT', 'MLflow', 'Optuna'],
    'Phase 3': ['FastAPI', 'Streamlit', 'Docker', 'Pydantic', 'ChromaDB'],
    'Phase 4': ['MLflow', 'DVC', 'GitHub Actions', 'Prometheus', 'Grafana'],
    'Phase 5': ['Locust', 'Redis', 'GPU', 'ReportLab', 'Compliance']
}

# Create technology evolution chart
fig, ax = plt.subplots(figsize=(15, 8))

# Create a stacked bar chart showing technology categories
categories = ['Data Processing', 'ML/AI', 'Web Development', 'MLOps', 'Enterprise']
phase_data = {
    'Phase 1': [4, 3, 0, 1, 0],
    'Phase 2': [1, 6, 0, 2, 0],
    'Phase 3': [0, 0, 5, 0, 0],
    'Phase 4': [0, 0, 0, 5, 0],
    'Phase 5': [0, 0, 0, 0, 5]
}

x = np.arange(len(phases))
width = 0.8

# Create stacked bars
bottom = np.zeros(len(phases))
colors_stack = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FFEAA7']

for i, category in enumerate(categories):
    values = [phase_data[phase][i] for phase in phases]
    ax.bar(x, values, width, bottom=bottom, label=category, color=colors_stack[i])
    bottom += values

ax.set_xlabel('Development Phases', fontsize=14, fontweight='bold')
ax.set_ylabel('Technology Count', fontsize=14, fontweight='bold')
ax.set_title('Technology Stack Evolution Across Phases', fontsize=16, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(phases, rotation=45, ha='right')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Business impact metrics
impact_metrics = {
    'Time Savings': {
        'Current': '4-6 hours per contract',
        'Phase 1': '2-3 hours per contract',
        'Phase 2': '1-2 hours per contract',
        'Phase 3': '30 minutes per contract',
        'Phase 4': '15 minutes per contract',
        'Phase 5': '5 minutes per contract'
    },
    'Risk Detection': {
        'Current': 'Manual review (70% accuracy)',
        'Phase 1': 'Keyword-based (80% accuracy)',
        'Phase 2': 'ML-based (90% accuracy)',
        'Phase 3': 'RAG-enhanced (92% accuracy)',
        'Phase 4': 'Production-tested (94% accuracy)',
        'Phase 5': 'Enterprise-grade (96% accuracy)'
    },
    'Cost Reduction': {
        'Current': 'Base cost',
        'Phase 1': '25% reduction',
        'Phase 2': '50% reduction',
        'Phase 3': '70% reduction',
        'Phase 4': '80% reduction',
        'Phase 5': '90% reduction'
    }
}

# Create business impact visualization
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for idx, (metric, data) in enumerate(impact_metrics.items()):
    stages = list(data.keys())
    values = list(data.values())
    
    # Convert to numeric where possible 
    numeric_values = []
    for value in values:
        if '%' in value:
            # Extract percentage number from various formats
            if 'reduction' in value:
                # Handle "25% reduction" format
                numeric_values.append(float(value.replace('%', '').replace(' reduction', '')))
            elif 'accuracy' in value:
                # Handle "70% accuracy" format - extract number from parentheses
                import re
                match = re.search(r'\((\d+)%', value)
                if match:
                    numeric_values.append(float(match.group(1)))
                else:
                    numeric_values.append(0)
            else:
                # Handle other percentage formats
                numeric_values.append(float(value.replace('%', '')))
        elif 'hours' in value or 'minutes' in value:
            # Handle time formats
            if 'hours' in value:
                # Extract numbers from range like "4-6" -> average of 4 and 6 = 5
                numbers = value.replace(' hours per contract', '').split('-')
                if len(numbers) == 2:
                    avg_hours = (float(numbers[0]) + float(numbers[1])) / 2
                    numeric_values.append(avg_hours * 60)  # Convert to minutes
                else:
                    numeric_values.append(float(numbers[0]) * 60)
            else:
                # Handle single minutes like "30 minutes"
                minutes = float(value.replace(' minutes per contract', ''))
                numeric_values.append(minutes)
        else:
            # Handle non-numeric values like "Base cost"
            numeric_values.append(0)
    
    bars = axes[idx].bar(range(len(stages)), numeric_values, 
                        color=colors[:len(stages)], alpha=0.7)
    
    # Add text labels
    for i, (stage, value) in enumerate(zip(stages, values)):
        axes[idx].text(i, numeric_values[i] + max(numeric_values)*0.05, value, 
                      ha='center', va='bottom', fontsize=8, rotation=45)
    
    axes[idx].set_title(metric, fontsize=14, fontweight='bold')
    axes[idx].set_xticks(range(len(stages)))
    axes[idx].set_xticklabels(stages, rotation=45, ha='right', fontsize=8)

plt.tight_layout()
plt.show()

# %%
# Quick start guide
print("🚀 Getting Started with Contract Analysis System")
print("=" * 60)

startup_steps = [
    "1. Clone the repository",
    "2. Set up conda environment: conda env create -f environment.yml",
    "3. Activate environment: conda activate contract-analysis",
    "4. Run Phase 1: python run_phase1.py",
    "5. Open notebooks: jupyter notebook",
    "6. Explore Phase 1: notebooks/01_phase1_foundations.ipynb"
]

for step in startup_steps:
    print(step)

print(f"\n�� Contact: mj.babaie@gmail.com")
print(f"🔗 LinkedIn: https://www.linkedin.com/in/mohammadbabaie/")
print(f"🐙 GitHub: https://github.com/Muh76")
print(f"\n🎯 Ready to revolutionize contract analysis!")
# Out:
# 🚀 Getting Started with Contract Analysis System
# ...
# 1. Clone the repository
# 2. Set up conda environment: conda env create -f environment.yml
# 3. Activate environment: conda activate contract-analysis
# 4. Run Phase 1: python run_phase1.py
# 5. Open notebooks: jupyter notebook
# 6. Explore Phase 1: notebooks/01_phase1_foundations.ipynb
#
# �� Contact: mj.babaie@gmail.com
# 🔗 LinkedIn: https://www.linkedin.com/in/mohammadbabaie/
# 🐙 GitHub: https://github.com/Muh76
#
# 🎯 Ready to revolutionize contract analysis!
